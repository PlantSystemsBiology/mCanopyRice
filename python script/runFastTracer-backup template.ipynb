# %% [markdown]
# # for 0711, 0724, 0810 and 0828
# # 9311 LA etc, NEED To change t

# %%
import os
stageDates=['0711','0724','0810','0828']
DOY=['192','205','222','240']

# %% [markdown]
# cultivarNames=['9311-ca1_F1','9311-CA2_F1','9311-ca1_CA2','9311-F1_ca1','9311-F1_CA2','9311-CA2_ca1']

# %% [markdown]
# cultivarNames=['JY5B-ca1_F1','JP69-CA2_F1','JY5B-ca1_CA2','JYY69-F1_ca1','JYY69-F1_CA2','JP69-CA2_ca1']

# %% [markdown]
# cultivarNames=['WYJ-ca1_F1','WYJ-CA2_F1','WYJ-ca1_CA2','WYJ-F1_ca1','WYJ-F1_CA2','WYJ-CA2_ca1']

# %%
cultivarNames=['Shao-F1_CA2','Shao-CA2_ca1']

# %%
traits=['TN','LN','SH','LL','LW','LS','LC','LA','TNLN']

# %% [markdown]
# t is used for select one of these traits

# %%
t=8

# %%
for s in range(1):
    s=s+2; # shift 2 for 0810 only
    for c in range(2):
        c=c+0; # shift 3
        cn=cultivarNames[c]
        for i in range(5):  # rep 5
            i=i+1
            print(i)
            cmdline='.\\FastTracer_2021\\fastTracerVS2019.exe -D 30 90 30 90 0 120 -L 31 -S 12 -A 0.7 -d '+DOY[s]+' -W 6.5 1 17.5 -n 0.1 -t 0.075 -r 0.075 -m .\\CM\\CM_'+stageDates[s]+'-'+cn+'-'+traits[t]+'-rep'+str(i)+'.txt -o .\\PPFD\\PPFD_'+stageDates[s]+'-'+cn+'-'+traits[t]+'-rep'+str(i)+'.txt'
            print(cmdline)
            f=os.popen(cmdline)
            data=f.readlines()
            f.close()
            print(data)
# Out:
# 1
# .\FastTracer_2021\fastTracerVS2019.exe -D 30 90 30 90 0 120 -L 31 -S 12 -A 0.7 -d 222 -W 6.5 1 17.5 -n 0.1 -t 0.075 -r 0.075 -m .\CM\CM_0810-Shao-F1_CA2-TNLN-rep1.txt -o .\PPFD\PPFD_0810-Shao-F1_CA2-TNLN-rep1.txt
# ...
