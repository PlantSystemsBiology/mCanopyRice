# %% [markdown]
# # for 0810 stage
# # JYY
# # 2024-04-07

# %%
import os
stageDates=['0711','0724','0810','0828']
DOY=['192','205','222','240']
s=2

# %%
cultivarNames=['JYY69_F1','JY5B_ca1','JP69_CA2']

# %%
traits=['TNLNLL']

# %%
t=0 # for the TNLNLL trait

# %%
adjTNvalues = [-2, -1, -1, 0, 0, 0, 1, 1, 2]
adjLNvalues = [0, -2,  0, -2, 0, 2, 0, 2, 0]

# %% [markdown]
# t is used for select one of these traits

# %%
rep=1

# %%
for c in range(3):
    cn=cultivarNames[c]
    for i in range(9):
        valueTN=adjTNvalues[i]
        valueLN=adjLNvalues[i]
        cmdline='..\\FastTracer_2021\\fastTracerVS2019.exe -D 30 90 30 90 0 120 -L 31 -S 12 -A 0.7 -d '+DOY[s]+' -W 6.5 1 17.5 -n 0.1 -t 0.075 -r 0.075 -m ..\\CM\\CM_'+stageDates[s]+'-'+cn+'-'+traits[t]+'_'+str(valueTN)+'_'+str(valueLN)+'-rep'+str(rep)+'.txt -o ..\\PPFD\\PPFD_'+stageDates[s]+'-'+cn+'-'+traits[t]+'_'+str(valueTN)+'_'+str(valueLN)+'-rep'+str(rep)+'.txt'
        print(cmdline)
        f=os.popen(cmdline)
        data=f.readlines()
        f.close()
        print(data)
# Out:
# ..\FastTracer_2021\fastTracerVS2019.exe -D 30 90 30 90 0 120 -L 31 -S 12 -A 0.7 -d 192 -W 6.5 1 17.5 -n 0.1 -t 0.075 -r 0.075 -m ..\CM\CM_0711-JYY69_F1-TNLNLL_-2_0-rep1.txt -o ..\PPFD\PPFD_0711-JYY69_F1-TNLNLL_-2_0-rep1.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 9
#       7 print(cmdline)
#       8 f=os.popen(cmdline)
# ----> 9 data=f.readlines()
#      10 f.close()
#      11 print(data)
#
# KeyboardInterrupt:
