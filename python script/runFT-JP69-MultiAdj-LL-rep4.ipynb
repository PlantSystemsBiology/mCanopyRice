# %% [markdown]
# # for 0810 stage
# # JYY
# # 2024-04-03

# %%
import os
stageDates=['0711','0724','0810','0828']
DOY=['192','205','222','240']
s=2

# %%
cultivarNames=['JP69-CA2']

# %%
traits=['TN','LN','SH','LL','LW','LS','LC','LA','TNLN']

# %%
t=3 # for the LL trait

# %% [markdown]
# adjustValues=[0.6, 0.7, 0.8, 0.9, 1.0, 1.1, 1.2, 1.3, 1.4]

# %%
adjustValues=[1.0]

# %%
adjustMode="MULTIPLY"

# %% [markdown]
# t is used for select one of these traits

# %%
rep=4

# %%
for c in range(1):
    cn=cultivarNames[c]
    for i in range(1):
        value=adjustValues[i]
        cmdline='..\\FastTracer_2021\\fastTracerVS2019.exe -D 30 90 30 90 0 120 -L 31 -S 12 -A 0.7 -d '+DOY[s]+' -W 6.5 1 17.5 -n 0.1 -t 0.075 -r 0.075 -m ..\\CM\\CM_'+stageDates[s]+'-'+cn+'-'+traits[t]+'_'+adjustMode+'_'+str(value)+'-rep'+str(rep)+'.txt -o ..\\PPFD\\PPFD_'+stageDates[s]+'-'+cn+'-'+traits[t]+'_'+adjustMode+'_'+str(value)+'-rep'+str(rep)+'.txt'
        print(cmdline)
        f=os.popen(cmdline)
        data=f.readlines()
        f.close()
        print(data)
# Out:
# ..\FastTracer_2021\fastTracerVS2019.exe -D 30 90 30 90 0 120 -L 31 -S 12 -A 0.7 -d 222 -W 6.5 1 17.5 -n 0.1 -t 0.075 -r 0.075 -m ..\CM\CM_0810-JP69-CA2-LL_MULTIPLY_1.0-rep4.txt -o ..\PPFD\PPFD_0810-JP69-CA2-LL_MULTIPLY_1.0-rep4.txt
# ...
